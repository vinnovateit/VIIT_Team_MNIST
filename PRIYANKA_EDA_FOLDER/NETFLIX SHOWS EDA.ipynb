# %% [markdown]
# # NETFLIX SHOWS : Exploratory Data Analysis (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('netflix_shows.csv',encoding='latin-1')

# %%
df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(50)
# Out:
#                                     title    rating  \
# 0                            White Chicks     PG-13
# 1                     Lucky Number Slevin         R
# 2                          Grey's Anatomy     TV-14
# 3                            Prison Break     TV-14
# 4                   How I Met Your Mother     TV-PG
# 5                            Supernatural     TV-14
# 6                            Breaking Bad     TV-MA
# 7                     The Vampire Diaries     TV-14
# 8                        The Walking Dead     TV-MA
# 9                     Pretty Little Liars     TV-14
# 10                       Once Upon a Time     TV-PG
# 11                               Sherlock     TV-14
# 12                             Death Note     TV-14
# 13                                 Naruto     TV-PG
# 14                             The Hunter         R
# 15                  Lottie Dottie Chicken      TV-Y
# 16                                  Arrow     TV-14
# ...

# %%
df.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   rating             1000 non-null   object
#  2   ratingLevel        941 non-null    object
#  3   ratingDescription  1000 non-null   int64
#  4   release year       1000 non-null   int64
#  5   user rating score  605 non-null    float64
#  6   user rating size   1000 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df.size
# Out:
# 7000

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.dtypes
# Out:
# title                 object
# rating                object
# ratingLevel           object
# ratingDescription      int64
# release year           int64
# user rating score    float64
# user rating size       int64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      3
# object     3
# float64    1
# dtype: int64

# %%
df.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                          title rating  \
# 0                 White Chicks  PG-13
# 1          Lucky Number Slevin      R
# 2               Grey's Anatomy  TV-14
# 3                 Prison Break  TV-14
# 4        How I Met Your Mother  TV-PG
# ..                         ...    ...
# 989            Russell Madness     PG
# 993  Wiener Dog Internationals      G
# 994                   Pup Star      G
# 997           Precious Puppies   TV-G
# 998                Beary Tales   TV-G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ...

# %%
df.shape
# Out:
# (500, 7)

# %%
df.hist()
plt.figure(figsize=(40,20))

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              500 non-null    object
#  1   rating             500 non-null    object
#  2   ratingLevel        467 non-null    object
#  3   ratingDescription  500 non-null    int64
#  4   release year       500 non-null    int64
#  5   user rating score  256 non-null    float64
#  6   user rating size   500 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 31.2+ KB

# %%
df.isnull()
# Out:
#      title  rating  ratingLevel  ratingDescription  release year  \
# 0    False   False        False              False         False
# 1    False   False        False              False         False
# 2    False   False        False              False         False
# 3    False   False        False              False         False
# 4    False   False        False              False         False
# ..     ...     ...          ...                ...           ...
# 989  False   False        False              False         False
# 993  False   False        False              False         False
# 994  False   False        False              False         False
# 997  False   False        False              False         False
# 998  False   False        False              False         False
#
#      user rating score  user rating size
# 0                False             False
# 1                 True             False
# 2                False             False
# ...

# %%
df.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           33
# ratingDescription      0
# release year           0
# user rating score    244
# user rating size       0
# dtype: int64

# %%
df[df.ratingDescription > 80]
# Out:
#                                                 title rating  \
# 1                                 Lucky Number Slevin      R
# 2                                      Grey's Anatomy  TV-14
# 3                                        Prison Break  TV-14
# 5                                        Supernatural  TV-14
# 6                                        Breaking Bad  TV-MA
# ..                                                ...    ...
# 475                                    Forensic Files  TV-14
# 479                                           Rectify  TV-14
# 485                                    American Crime  TV-14
# 486                                   Madam Secretary  TV-14
# 493  American Crime Story: The People v. O.J. Simpson  TV-MA
#
#                                            ratingLevel  ratingDescription  \
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %%
rating_freq = df['rating'].value_counts()
plt.figure(figsize=(40,20))
rating_freq.plot.bar(color='Red',alpha=0.5)
plt.xlabel("Ratings")
plt.ylabel("Freq of ratings")
plt.title("RATING")
# Out:
# Text(0.5, 1.0, 'RATING')

# %%
from matplotlib import style
style.use('ggplot')
rating_freq = df['rating'].value_counts()
plt.figure(figsize=(20,10))
rating_freq.plot.line(color='Red',linewidth=4)
plt.xlabel("Ratings")
plt.ylabel("Freq of ratings")
plt.title("RATING")
# Out:
# Text(0.5, 1.0, 'RATING')

# %%
rating_freq = df['rating'].value_counts()
plt.figure(figsize=(20,10))
rating_freq.plot.pie()
#plt.xlabel("Ratings")
#plt.ylabel("Freq of ratings")
plt.title("RATING")
# Out:
# Text(0.5, 1.0, 'RATING')

# %%
year_freq = df['release year'].value_counts().sort_values(ascending= True)
plt.figure(figsize=(20,10))
year_freq.plot.bar(color='green')
plt.xlabel("Release Years")
plt.ylabel("Movies Released")
plt.title("Movies Released Vs Release Years: Bar Graph")
plt.show()

# %%
year_freq = df['release year'].value_counts().sort_values(ascending= True)
plt.figure(figsize=(20,10))
year_freq.plot.pie()
#plt.xlabel("Release Years")
#plt.ylabel("Movies Released")
plt.title("Movies Released Vs Release Years: Pie Chart")
plt.show()

# %%
from matplotlib import style
style.use('ggplot')
year_freq = df['release year'].value_counts().sort_values(ascending= True)
plt.figure(figsize=(20,10))
year_freq.plot.line(color='purple' ,linewidth=4)
plt.xlabel("Release Years")
plt.ylabel("Movies Released")
plt.title("Movies Released Vs Release Years: Graph")
plt.show()
