# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\RITODEEP\Downloads\dataset\train_.csv',encoding='latin-1')
df
# Out:
#         Unnamed: 0            id  click      hour    C1  banner_pos   site_id  \
# 0                0  1.000009e+18      0  14102100  1005           0  1fbe01fe
# 1                1  1.000017e+19      0  14102100  1005           0  1fbe01fe
# 2                2  1.000037e+19      0  14102100  1005           0  1fbe01fe
# 3                3  1.000064e+19      0  14102100  1005           0  1fbe01fe
# 4                4  1.000068e+19      0  14102100  1005           1  fe8cc448
# ...            ...           ...    ...       ...   ...         ...       ...
# 499995      499995  1.311196e+19      0  14102103  1005           0  85f751fd
# 499996      499996  1.311197e+19      0  14102103  1005           1  d9750ee7
# 499997      499997  1.311202e+19      0  14102103  1005           0  85f751fd
# 499998      499998  1.311205e+19      0  14102103  1005           1  5b4d2eda
# 499999      499999  1.311207e+18      1  14102103  1005           0  2328ee8e
#
# ...

# %%
print(df.isnull().sum())
df.isnull().sum().sum()
# Out:
# Unnamed: 0          0
# id                  0
# click               0
# hour                0
# C1                  0
# banner_pos          0
# site_id             0
# site_domain         0
# site_category       0
# app_id              0
# app_domain          0
# app_category        0
# device_id           0
# device_ip           0
# device_model        0
# device_type         0
# device_conn_type    0
# C14                 0
# C15                 0
# C16                 0
# C17                 0
# C18                 0
# C19                 0
# C20                 0
# C21                 0
# dtype: int64
# 0

# %%
df["tstamp"] = pd.to_datetime(df["hour"], format="%y%m%d%H")
df["year"] = df["tstamp"].dt.year
df["month"] = df["tstamp"].dt.month
df["day"] = df["tstamp"].dt.day
df["hours"] = df["tstamp"].dt.hour
df
# Out:
#         Unnamed: 0            id  click      hour    C1  banner_pos   site_id  \
# 0                0  1.000009e+18      0  14102100  1005           0  1fbe01fe
# 1                1  1.000017e+19      0  14102100  1005           0  1fbe01fe
# 2                2  1.000037e+19      0  14102100  1005           0  1fbe01fe
# 3                3  1.000064e+19      0  14102100  1005           0  1fbe01fe
# 4                4  1.000068e+19      0  14102100  1005           1  fe8cc448
# ...            ...           ...    ...       ...   ...         ...       ...
# 499995      499995  1.311196e+19      0  14102103  1005           0  85f751fd
# 499996      499996  1.311197e+19      0  14102103  1005           1  d9750ee7
# 499997      499997  1.311202e+19      0  14102103  1005           0  85f751fd
# 499998      499998  1.311205e+19      0  14102103  1005           1  5b4d2eda
# 499999      499999  1.311207e+18      1  14102103  1005           0  2328ee8e
#
# ...

# %%
a=df.pop('click')
df['click']=a

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        500000 non-null  int64
#  1   id                500000 non-null  float64
#  2   hour              500000 non-null  int64
#  3   C1                500000 non-null  int64
#  4   banner_pos        500000 non-null  int64
#  5   site_id           500000 non-null  object
#  6   site_domain       500000 non-null  object
#  7   site_category     500000 non-null  object
#  8   app_id            500000 non-null  object
#  9   app_domain        500000 non-null  object
#  10  app_category      500000 non-null  object
#  11  device_id         500000 non-null  object
#  12  device_ip         500000 non-null  object
#  13  device_model      500000 non-null  object
#  14  device_type       500000 non-null  int64
#  15  device_conn_type  500000 non-null  int64
# ...

# %%
sns.countplot(df['click'], data=df)

# %% [markdown]
# **INFERENCE - The graph shows the number who haven't clicked is far more**

# %%
from pandas.plotting import scatter_matrix  
scatter_matrix(df[['hours', 'year','month', 'day','click','banner_pos']],  
 alpha=0.3, figsize=(10,10));
# Out:
# C:\Users\RITODEEP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 2014.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\RITODEEP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 10.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\RITODEEP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 21.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\RITODEEP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:81: UserWarning: Attempting to set identical bottom == top == 2014.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# ...

# %% [markdown]
# **There is no particular trend shown between hour,days,months and banner position**

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.iloc[:,25:].corr(),annot=True)
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# **The above graph shows that there is no such correlation between hours, month, day,and year. Year, Month and Day remains constannt throughout**

# %%
df=pd.DataFrame(df,columns=['Unnamed: 0', 'id', 'hour','site_id',
       'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category',
       'device_id', 'device_ip', 'device_model', 'device_type',
       'device_conn_type','year', 'month', 'day', 'hours', 'banner_pos', 'C1', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
       'C21', 'click'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 29 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        500000 non-null  int64
#  1   id                500000 non-null  float64
#  2   hour              500000 non-null  int64
#  3   site_id           500000 non-null  object
#  4   site_domain       500000 non-null  object
#  5   site_category     500000 non-null  object
#  6   app_id            500000 non-null  object
#  7   app_domain        500000 non-null  object
#  8   app_category      500000 non-null  object
#  9   device_id         500000 non-null  object
#  10  device_ip         500000 non-null  object
#  11  device_model      500000 non-null  object
#  12  device_type       500000 non-null  int64
#  13  device_conn_type  500000 non-null  int64
#  14  year              500000 non-null  int64
#  15  month             500000 non-null  int64
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.iloc[:,19:].corr(),annot=True)
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# **Apart from C14 and C17 there is no such correlation among the anymous parameters**

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.iloc[:,14:].corr(),annot=True)
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# **Overall the features show almost no correlation**

# %%
plt.figure(figsize=(10, 10))
sns.distplot(df['hours'][df['click']==1], color='green')
sns.distplot(df['hours'][df['click']==0], color='red')
plt.legend(["1","0"]) 
plt.show()

# %% [markdown]
# **At 2 hours the clicks are the maximum, with maximum no clicks**

# %%
plt.figure(figsize=(10, 10))
sns.countplot(df['banner_pos'][df['click']==1])
plt.show()

# %% [markdown]
# **Most of the clicks occur at banner position 0**

# %%
plt.figure(figsize=(10, 10))
sns.countplot(df['hours'][df['click']==1])
plt.show()

# %% [markdown]
# **Most of the clicks occur at hour 2**

# %%
plt.figure(figsize=(10,10))
x = df['C14']
y = df['C17']
plt.scatter(x, y)

# %% [markdown]
# **The graph shows the realtion between parameters C14 and C17**

# %%
sns.pairplot(df, hue = 'click', vars = ['hours', 'banner_pos' ,'C1','C14','C17'],palette = 'mako')
# Out:
# C:\Users\RITODEEP\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\RITODEEP\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\RITODEEP\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Apart from C14 and C17 there no such relation, where most of the occurrences are discrete**

# %%
df
# Out:
#         Unnamed: 0            id      hour    C1  banner_pos   site_id  \
# 0                0  1.000009e+18  14102100  1005           0  1fbe01fe
# 1                1  1.000017e+19  14102100  1005           0  1fbe01fe
# 2                2  1.000037e+19  14102100  1005           0  1fbe01fe
# 3                3  1.000064e+19  14102100  1005           0  1fbe01fe
# 4                4  1.000068e+19  14102100  1005           1  fe8cc448
# ...            ...           ...       ...   ...         ...       ...
# 499995      499995  1.311196e+19  14102103  1005           0  85f751fd
# 499996      499996  1.311197e+19  14102103  1005           1  d9750ee7
# 499997      499997  1.311202e+19  14102103  1005           0  85f751fd
# 499998      499998  1.311205e+19  14102103  1005           1  5b4d2eda
# 499999      499999  1.311207e+18  14102103  1005           0  2328ee8e
#
#        site_domain site_category    app_id app_domain  ...   C17 C18   C19  \
# ...

# %%
df=pd.DataFrame(df,columns=['Unnamed: 0', 'id', 'hour','site_id',
       'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category', 'device_model', 'device_type',
       'device_conn_type','hours', 'banner_pos', 'C1', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
       'C21', 'click'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        500000 non-null  int64
#  1   id                500000 non-null  float64
#  2   hour              500000 non-null  int64
#  3   site_id           500000 non-null  object
#  4   site_domain       500000 non-null  object
#  5   site_category     500000 non-null  object
#  6   app_id            500000 non-null  object
#  7   app_domain        500000 non-null  object
#  8   app_category      500000 non-null  object
#  9   device_model      500000 non-null  object
#  10  device_type       500000 non-null  int64
#  11  device_conn_type  500000 non-null  int64
#  12  hours             500000 non-null  int64
#  13  banner_pos        500000 non-null  int64
#  14  C1                500000 non-null  int64
#  15  C14               500000 non-null  int64
# ...

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'hour', 'site_id', 'site_domain', 'site_category',
#        'app_id', 'app_domain', 'app_category', 'device_model', 'device_type',
#        'device_conn_type', 'hours', 'banner_pos', 'C1', 'C14', 'C15', 'C16',
#        'C17', 'C18', 'C19', 'C20', 'C21', 'click'],
#       dtype='object')

# %%
x_train=pd.DataFrame(x_train,columns = ['Unnamed: 0', 'id', 'hour', 'site_id', 'site_domain', 'site_category',
       'app_id', 'app_domain', 'app_category', 'device_model', 'device_type',
       'device_conn_type', 'hours', 'banner_pos', 'C1', 'C14', 'C15', 'C16',
       'C17', 'C18', 'C19', 'C20', 'C21'])

# %%
x_test=pd.DataFrame(x_test,columns = ['Unnamed: 0', 'id', 'hour', 'site_id', 'site_domain', 'site_category',
       'app_id', 'app_domain', 'app_category', 'device_model', 'device_type',
       'device_conn_type', 'hours', 'banner_pos', 'C1', 'C14', 'C15', 'C16',
       'C17', 'C18', 'C19', 'C20', 'C21'])

# %%
y_train=pd.DataFrame(y_train,columns = ['click'])
y_test=pd.DataFrame(y_test,columns = ['click'])

# %%
x_train_dict = list(x_train.T.to_dict().values())
x_test_dict = list(x_test.T.to_dict().values())

# %%
from sklearn.feature_extraction import DictVectorizer

vectorizer = DictVectorizer(sparse=True)
x_train = vectorizer.fit_transform(x_train_dict)
x_test = vectorizer.transform(x_test_dict)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(x_train, y_train)
# Out:
# C:\Users\RITODEEP\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\RITODEEP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.83661

# %% [markdown]
# **The following model has an accuracy of 83.661%**
