# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(r'C:\Users\RITODEEP\Downloads\Netflix Shows.csv',encoding='latin-1')
df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
print(df.isnull().sum())
df.isnull().sum().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64
# 454

# %% [markdown]
# Checking Null Values

# %%
df1=df.dropna()
df1.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Deleting null values

# %%
df1.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80
# 5          2016               95.0                80

# %%
df.duplicated().sum()
# Out:
# 500

# %% [markdown]
# Finding number of duplicates

# %%
df=df[df.duplicated()==False]
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Deleting Duplicates

# %%
df1.reset_index(inplace=True)
df1.head()
# Out:
#    index                  title rating  \
# 0      0           White Chicks  PG-13
# 1      2         Grey's Anatomy  TV-14
# 2      3           Prison Break  TV-14
# 3      4  How I Met Your Mother  TV-PG
# 4      5           Supernatural  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  Parents strongly cautioned. May be unsuitable ...                 90
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parental guidance suggested. May not be suitab...                 70
# 4  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2016               98.0                80
# 2          2008               98.0                80
# 3          2014               94.0                80
# ...

# %% [markdown]
# Resetting The Index Numbers

# %%
rec=[]
for i in range(len(df1['user rating score'])):
    if df1['user rating score'][i]>=90.0:
        rec.append('A must watch')
    if df1['user rating score'][i]>=80.0 and df1['user rating score'][i]<90.0:
        rec.append("Highly reccomended")
    if df1['user rating score'][i]>=70.0 and df1['user rating score'][i]<80.0:
        rec.append('Recommended')
    if df1['user rating score'][i]>=50.0 and df1['user rating score'][i]<70:
        rec.append('A one time watch')
    if df1['user rating score'][i]<50.0:
        rec.append('Can be skipped')
df1['Recommendation']=rec
df1
# Out:
# <ipython-input-16-cc1fc48478e9>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Recommendation']=rec
#      index                    title rating  \
# 0        0             White Chicks  PG-13
# 1        2           Grey's Anatomy  TV-14
# 2        3             Prison Break  TV-14
# 3        4    How I Met Your Mother  TV-PG
# 4        5             Supernatural  TV-14
# ..     ...                      ...    ...
# 569    984     The Magic School Bus   TV-Y
# 570    986  PokÌ©mon: Indigo League   TV-Y
# 571    988               Paddington     PG
# 572    991       Dawn of the Croods  TV-Y7
# 573    995                  The BFG     PG
#
#                                            ratingLevel  ratingDescription  \
# ...

# %% [markdown]
# Adding a new column recommendation which recommends movies based on user rating

# %%
df3=df1.sort_values(by=['release year'],ascending=False)
df3
# Out:
#      index               title rating  \
# 82     141      13 Reasons Why  TV-MA
# 63      97         Chewing Gum  TV-MA
# 84     148      Dave Chappelle  TV-MA
# 83     143         Chewing Gum  TV-MA
# 81     135  Santa Clarita Diet  TV-MA
# ..     ...                 ...    ...
# 177    301              Grease     PG
# 133    252              Grease     PG
# 524    861            Fantasia      G
# 540    907            Fantasia      G
# 494    761            Fantasia      G
#
#                                            ratingLevel  ratingDescription  \
# 82   For mature audiences.  May not be suitable for...                110
# 63   For mature audiences.  May not be suitable for...                110
# 84   For mature audiences.  May not be suitable for...                110
# 83   For mature audiences.  May not be suitable for...                110
# 81   For mature audiences.  May not be suitable for...                110
# ...

# %% [markdown]
# Arranging the shows based on their release year (newest to oldest)

# %%
df4=df1.sort_values(by=['user rating score'],ascending=False)
df4
# Out:
#                                 title    rating  \
# 41                     13 Reasons Why     TV-MA
# 63                     Criminal Minds     TV-14
# 3                        Prison Break     TV-14
# 64                            Friends     TV-14
# 2                      Grey's Anatomy     TV-14
# ..                                ...       ...
# 667  DreamWorks Shrek's Swamp Stories     TV-PG
# 594                      PokÌ©mon: XY  TV-Y7-FV
# 380                            Bitten     TV-MA
# 710                    Curious George         G
# 207                   Life Unexpected     TV-PG
#
#                                            ratingLevel  ratingDescription  \
# 41   For mature audiences.  May not be suitable for...                110
# 63   Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 64   Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %% [markdown]
# Arranging the shows based on their rating (highest to lowest)

# %%
plt.figure(figsize=(50,20))
plt.title("Graph of movie released in an year",fontsize=50)
x=df1['release year']
y=df1['user rating score']
plt.plot(x,y,linewidth=3)
plt.xlabel("Year",fontsize=50)
plt.ylabel("User rating Score",fontsize=50)
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.title("Graph of movie released in an year",fontsize=50)
x=df1['release year']
y=df1['user rating score']

plt.xlabel("Year",fontsize=50)
plt.ylabel("'user rating score'",fontsize=50)
plt.bar(x,y,width = 1, color = ['red', 'green'])
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.title("Rating vs Shows released in a particular year", fontsize = 20)

x=df1['release year']
y=df1['user rating score']

plt.xlabel('Shows released in a year',fontsize=15)
plt.ylabel('User rating Score',fontsize=15)
plt.scatter(x, y,alpha = 0.5)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title("Graph of movie released in an year",fontsize=20)
rel=df1['release year'].value_counts()
plt.xlabel("Year",fontsize=15)
plt.ylabel("Number of movies release",fontsize=15)
rel.plot.line(linewidth=3)

# %%
plt.figure(figsize=(30,10))
rel.plot.pie()
plt.title("Number of movies released in an year",)
# Out:
# Text(0.5, 1.0, 'Number of movies released in an year')
